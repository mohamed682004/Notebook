# %% [markdown]
# Title: Notebook

# %% [markdown]
# introducing you this notebook

# %% [markdown]
# Python
#
# R
#
# SQL
#
# Scala
#
# Java
#
# C++
#
# Julia
#
# JavaScript
#
# PHP
#
# Go
#
# Ruby
#
# Visual Basic

# %% [markdown]
# Pandas
#
# Numpy
#
# Matplotlib
#
# Seaborn
#
# Scikit-learn
#
# Keras
#
# TensorFlow
#
# PyTorch
#
# Apache Spark
#
# Vegas
#
# Big DL
#
# Ggplot2

# %% [markdown]
# anaconda
#
# Spyder
#
# R Studio

# %% [markdown]
# _i will show You some equations under his markdown_

# %%
(5+9)*60
# Out:
# 840

# %%
120//60
# Out:
# 2

# %% [markdown]
# i dont know what objectives to be wroe here

# %% [markdown]
# __AUTHOR__
# _MOHAMMED_
